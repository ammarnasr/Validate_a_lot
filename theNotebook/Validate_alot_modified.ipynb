# %%
# !nvidia-smi #Fri Jun 19 18:08:52 2020

# %%
import os
# !rm -r /content/sample_data/

# %%
os.chdir('/content')
# !rm -r AttnGAN
# !git clone https://github.com/taoxugit/AttnGAN.git

# %%
os.chdir('/content/AttnGAN/data/')
#!wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1O_LtUP9sch09QH3s_EBAgLEctBQ5JBSJ' -O birds.zip
# !cp '/content/drive/My Drive/birds/birds.zip' '/content/AttnGAN/data/'
# !unzip -q birds.zip
# !rm birds.zip
# !rm -r __MACOSX/

# %%
os.chdir('/content/AttnGAN/data/birds')
# !unzip -q text.zip
# !rm text.zip

# %%
#Changing Working dirctory to birds
os.chdir('/content/AttnGAN/data/birds/')
# !cp '/content/drive/My Drive/cub/CUB_200_2011.tgz' '/content/AttnGAN/data/birds/'
# !tar zxf  CUB_200_2011.tgz
# !rm CUB_200_2011.tgz

# %%
os.chdir('/content/AttnGAN/code/')
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1Wr3lQajG7m6Bi3rYFTJb6mwE_d8su111' -O Pillow.rar
# !unrar x  Pillow.rar
# !rm Pillow.rar

# %%
os.chdir('/content/AttnGAN/DAMSMencoders/')
os.mkdir('bird')

# %%
os.chdir('/content')
#Dwonload files config.py, utils.py, datasets.py, pretrain_DAMSM.py
# !git clone https://github.com/ammarnasr/CUB-Attn-GAN.git

# #Move Models text and image encoder to their /content/
# !mv /content/CUB-Attn-GAN/theModel/text_encoder599.pth /content/
# !mv /content/CUB-Attn-GAN/theModel/image_encoder599.pth /content/
# !mv /content/CUB-Attn-GAN/theCode/GAN/netG_epoch_600.pth /content/

#Remove the Repo
# !rm -r /content/CUB-Attn-GAN/

#Move Models text and image encoder to their /content/
# !mv /content/text_encoder599.pth /content/AttnGAN/DAMSMencoders/bird/
# !mv /content/image_encoder599.pth /content/AttnGAN/DAMSMencoders/bird/
# !mv /content/netG_epoch_600.pth /content/AttnGAN/models/

# %%
# !cp -a '/content/drive/My Drive/ModifiedcubModelGAN/.' '/content/AttnGAN/models/'

# %% [markdown]
# ===================================================================================================================

# %%
os.chdir('/content')
# !rm -r Validate_a_lot
# !git clone https://github.com/ammarnasr/Validate_a_lot.git

# %%
# !mv /content/Validate_a_lot/code/utils.py /content/AttnGAN/code/miscc/
# !mv /content/Validate_a_lot/code/config.py /content/AttnGAN/code/miscc/
# !mv /content/Validate_a_lot/code/datasets.py /content/AttnGAN/code/
# !mv /content/Validate_a_lot/code/main.py /content/AttnGAN/code/
# !mv /content/Validate_a_lot/code/trainer.py /content/AttnGAN/code/
# !mv /content/Validate_a_lot/code/eval_bird.yml /content/AttnGAN/code/cfg/


# !mv /content/Validate_a_lot/code/modified/model.py /content/AttnGAN/code/
# !mv /content/Validate_a_lot/code/modified/GlobalAttention.py /content/AttnGAN/code/

# %%
## Adjust netG_list in trainer.py


os.chdir('/content/AttnGAN/code')
# !python main.py --cfg cfg/eval_bird.yml --gpu 0
# Out:
# Using config:
# {'B_VALIDATION': True,
#  'CONFIG_NAME': 'attn2',
#  'CUDA': True,
#  'DATASET_NAME': 'birds',
#  'DATA_DIR': '../data/birds',
#  'GAN': {'B_ATTENTION': True,
#          'B_DCGAN': False,
#          'CONDITION_DIM': 100,
#          'DF_DIM': 64,
#          'GF_DIM': 32,
#          'R_NUM': 2,
#          'Z_DIM': 100},
#  'GPU_ID': 0,
#  'RNN_TYPE': 'LSTM',
#  'TEXT': {'CAPTIONS_PER_IMAGE': 10, 'EMBEDDING_DIM': 256, 'WORDS_NUM': 25},
#  'TRAIN': {'BATCH_SIZE': 32,
#            'B_NET_D': False,
#            'DISCRIMINATOR_LR': 0.0002,
#            'ENCODER_LR': 0.0002,
#            'FLAG': False,
#            'GENERATOR_LR': 0.0002,
#            'MAX_EPOCH': 600,
#            'NET_E': '../DAMSMencoders/bird/text_encoder599.pth',
#            'NET_G': '../models/netG_epoch_600.pth',
#            'RNN_GRAD_CLIP': 0.25,
#            'SMOOTH': {'GAMMA1': 5.0,
#                       'GAMMA2': 5.0,
#                       'GAMMA3': 10.0,
#                       'LAMBDA': 1.0},
#            'SNAPSHOT_INTERVAL': 2000},
#  'TREE': {'BASE_SIZE': 64, 'BRANCH_NUM': 3},
#  'WORKERS': 1}
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/transforms.py:257: UserWarning: The use of the transforms.Scale transform is deprecated, please use transforms.Resize instead.
#   "please use transforms.Resize instead.")
# Total filenames:  11788 001.Black_footed_Albatross/Black_Footed_Albatross_0046_18.jpg
# Load filenames from: ../data/birds/train/filenames.pickle (8855)
# Load filenames from: ../data/birds/test/filenames.pickle (2933)
# Load from:  ../data/birds/captions.pickle
# /content/AttnGAN/code/miscc/utils.py:404: UserWarning: nn.init.orthogonal is now deprecated in favor of nn.init.orthogonal_.
#   nn.init.orthogonal(m.weight.data, 1.0)
# /content/AttnGAN/code/miscc/utils.py:399: UserWarning: nn.init.orthogonal is now deprecated in favor of nn.init.orthogonal_.
#   nn.init.orthogonal(m.weight.data, 1.0)
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/rnn.py:60: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# Load text encoder from: ../DAMSMencoders/bird/text_encoder599.pth
# /content/AttnGAN/code/trainer.py:442: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   noise = Variable(torch.FloatTensor(batch_size, nz), volatile=True)
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_0.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_0/valid
# step:  0
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1625: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# /content/AttnGAN/code/GlobalAttention.py:115: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   attn = self.sm(attn)  # Eq. (2)
# /content/AttnGAN/code/GlobalAttention.py:134: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   sent_att                = nn.Softmax()(sentence_vs)  # batch x idf x ih x iw
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_10.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_10/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_20.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_20/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_30.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_30/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_40.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_40/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_50.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_50/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_60.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_60/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_70.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_70/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_80.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_80/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_90.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_90/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_100.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_100/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_110.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_110/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_120.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_120/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_130.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_130/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_140.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_140/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_150.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_150/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_160.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_160/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_170.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_170/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_180.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_180/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_190.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_190/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_200.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_200/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_210.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_210/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_220.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_220/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_230.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_230/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_240.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_240/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_250.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_250/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_260.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_260/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_270.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_270/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_280.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_280/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_290.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_290/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_300.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_300/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_310.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_310/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_320.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_320/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_330.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_330/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_340.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_340/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_350.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_350/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_360.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_360/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_370.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_370/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_380.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_380/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_390.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_390/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_400.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_400/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_410.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_410/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_420.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_420/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_430.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_430/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_440.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_440/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_450.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_450/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_460.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_460/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_470.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_470/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_480.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_480/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_490.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_490/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_500.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_500/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_510.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_510/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_520.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_520/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_530.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_530/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_540.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_540/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_550.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_550/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_560.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_560/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_570.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_570/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_580.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_580/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_590.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_590/valid
# step:  0
# ----------state-dict---------------------
# Load G from:  ../models/netG_epoch_600.pth
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# save_dir: ../models/netG_epoch_600/valid
# step:  0
# Total time for training: 6323.963319301605

# %% [markdown]
# # Validiate

# %%
import os
os.chdir('/content')

# %%
os.chdir('/content')
# !git clone https://github.com/hanzhanggit/StackGAN-inception-model.git

# %%
os.chdir('/content/StackGAN-inception-model/')
#!wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=0B3y_msrWZaXLMzNMNWhWdW0zVWs' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=0B3y_msrWZaXLMzNMNWhWdW0zVWs" -O inception_finetuned_models.zip && rm -rf /tmp/cookies.txt
# !cp '/content/drive/My Drive/inception/inception_finetuned_models.zip' '/content/StackGAN-inception-model/'
# !unzip -q inception_finetuned_models.zip
# !rm inception_finetuned_models.zip
# !rm README.md
# !rm -r __MACOSX/

# %%
# !pip install scipy==1.1.0

# %%
os.chdir('/content')
# !rm -r Validate_a_lot
# !git clone https://github.com/ammarnasr/Validate_a_lot.git

# %%
# !mv /content/Validate_a_lot/code/inception_score.py /content/StackGAN-inception-model/

# %%
## Adjust imagePathList in inception_score.py


os.chdir('/content/StackGAN-inception-model/')
# %tensorflow_version 1.x
# !python inception_score.py --image_folder '/content/AttnGAN/models/netG_epoch_60/valid/single/'
# Out:
# TensorFlow 1.x selected.
# /content/AttnGAN/models/netG_epoch_60/valid/single/
# WARNING:tensorflow:From inception_score.py:350: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From inception_score.py:233: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0820 15:57:43.087667 139642231138176 module_wrapper.py:139] From inception_score.py:233: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From inception_score.py:235: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0820 15:57:43.087953 139642231138176 module_wrapper.py:139] From inception_score.py:235: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-08-20 15:57:43.105968: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-08-20 15:57:43.106292: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x22a9480 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-08-20 15:57:43.106324: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-08-20 15:57:43.121686: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-08-20 15:57:43.302288: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-20 15:57:43.302989: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x608c700 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-08-20 15:57:43.303024: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2020-08-20 15:57:43.303261: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-20 15:57:43.303810: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-08-20 15:57:43.322498: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-08-20 15:57:43.537866: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-08-20 15:57:43.695978: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-08-20 15:57:43.711860: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-08-20 15:57:43.942077: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-08-20 15:57:44.009382: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-08-20 15:57:44.503843: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-20 15:57:44.504059: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-20 15:57:44.504793: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-20 15:57:44.505344: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-08-20 15:57:44.507451: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-08-20 15:57:44.508698: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-08-20 15:57:44.508726: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-08-20 15:57:44.508737: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-08-20 15:57:44.509716: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-20 15:57:44.510307: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-20 15:57:44.510862: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14221 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# WARNING:tensorflow:From inception_score.py:243: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0820 15:57:44.512089 139642231138176 module_wrapper.py:139] From inception_score.py:243: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/StackGAN-inception-model/inception/slim/ops.py:213: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0820 15:57:44.518580 139642231138176 module_wrapper.py:139] From /content/StackGAN-inception-model/inception/slim/ops.py:213: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/StackGAN-inception-model/inception/slim/variables.py:279: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# W0820 15:57:44.519385 139642231138176 module_wrapper.py:139] From /content/StackGAN-inception-model/inception/slim/variables.py:279: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/StackGAN-inception-model/inception/slim/variables.py:287: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0820 15:57:44.519730 139642231138176 module_wrapper.py:139] From /content/StackGAN-inception-model/inception/slim/variables.py:287: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /content/StackGAN-inception-model/inception/slim/ops.py:367: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0820 15:57:44.597210 139642231138176 module_wrapper.py:139] From /content/StackGAN-inception-model/inception/slim/ops.py:367: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /content/StackGAN-inception-model/inception/slim/ops.py:397: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# W0820 15:57:44.831856 139642231138176 module_wrapper.py:139] From /content/StackGAN-inception-model/inception/slim/ops.py:397: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /content/StackGAN-inception-model/inception/slim/ops.py:314: The name tf.nn.xw_plus_b is deprecated. Please use tf.compat.v1.nn.xw_plus_b instead.
#
# W0820 15:57:46.060217 139642231138176 module_wrapper.py:139] From /content/StackGAN-inception-model/inception/slim/ops.py:314: The name tf.nn.xw_plus_b is deprecated. Please use tf.compat.v1.nn.xw_plus_b instead.
#
# WARNING:tensorflow:From inception_score.py:256: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W0820 15:57:46.573854 139642231138176 module_wrapper.py:139] From inception_score.py:256: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# INFO:tensorflow:Restoring parameters from ./inception_finetuned_models/birds_valid299/model.ckpt
# I0820 15:57:46.844851 139642231138176 saver.py:1284] Restoring parameters from ./inception_finetuned_models/birds_valid299/model.ckpt
# Restore the model from ./inception_finetuned_models/birds_valid299/model.ckpt).
# /content/AttnGAN/models/netG_epoch_0/valid/single/
# images 2912 (256, 256, 3)
# 2020-08-20 15:58:07.894899: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 68659968 exceeds 10% of system memory.
# 2020-08-20 15:58:08.594883: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-08-20 15:58:10.078557: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# Batch  0
# inp (64, 299, 299, 3) 0.84313726 -0.827451
# pred (64, 50) 0.1261126 0.000989568
# Batch  25
# inp (64, 299, 299, 3) 0.75686276 -0.7882353
# pred (64, 50) 0.16708425 0.0011244535
# ################################################################################
# mean: 1.05 std: 0.00
# Mean Inception Score : 1.054229497909546
# ################################################################################
# /content/AttnGAN/models/netG_epoch_10/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.9843137 -1.0
# pred (64, 50) 0.8444477 0.0003419245
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9522086 9.471791e-05
# ################################################################################
# mean: 2.77 std: 0.08
# Mean Inception Score : 2.771920919418335
# ################################################################################
# /content/AttnGAN/models/netG_epoch_20/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9261149 0.00014058546
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.8623092 0.00031987287
# ################################################################################
# mean: 3.78 std: 0.14
# Mean Inception Score : 3.775662660598755
# ################################################################################
# /content/AttnGAN/models/netG_epoch_30/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.95841765 2.3482049e-05
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.96617484 2.3708939e-05
# ################################################################################
# mean: 4.00 std: 0.13
# Mean Inception Score : 3.999910354614258
# ################################################################################
# /content/AttnGAN/models/netG_epoch_40/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9104519 0.00022278616
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9410522 0.000109128974
# ################################################################################
# mean: 3.97 std: 0.17
# Mean Inception Score : 3.9741714000701904
# ################################################################################
# /content/AttnGAN/models/netG_epoch_50/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.955564 6.718425e-05
# Batch  25
# inp (64, 299, 299, 3) 1.0 -1.0
# pred (64, 50) 0.98628485 6.415499e-06
# ################################################################################
# mean: 4.11 std: 0.14
# Mean Inception Score : 4.105579853057861
# ################################################################################
# /content/AttnGAN/models/netG_epoch_60/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.95717335 0.00015744018
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9629425 0.00014608858
# ################################################################################
# mean: 4.00 std: 0.25
# Mean Inception Score : 4.003464698791504
# ################################################################################
# /content/AttnGAN/models/netG_epoch_70/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.94500434 6.859498e-05
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.94163615 8.179607e-05
# ################################################################################
# mean: 4.13 std: 0.13
# Mean Inception Score : 4.133843421936035
# ################################################################################
# /content/AttnGAN/models/netG_epoch_80/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.87776774 0.00024207745
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9105008 0.00021199175
# ################################################################################
# mean: 4.03 std: 0.13
# Mean Inception Score : 4.0257062911987305
# ################################################################################
# /content/AttnGAN/models/netG_epoch_90/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.88755727 0.00035981502
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.96252394 7.197382e-05
# ################################################################################
# mean: 4.03 std: 0.13
# Mean Inception Score : 4.030735015869141
# ################################################################################
# /content/AttnGAN/models/netG_epoch_100/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.91840386 0.00020802743
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9114638 0.000110001456
# ################################################################################
# mean: 4.18 std: 0.14
# Mean Inception Score : 4.1794233322143555
# ################################################################################
# /content/AttnGAN/models/netG_epoch_110/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9164861 0.0004431717
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.96036106 0.0002287294
# ################################################################################
# mean: 4.10 std: 0.17
# Mean Inception Score : 4.099281311035156
# ################################################################################
# /content/AttnGAN/models/netG_epoch_120/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.8939859 0.0003396074
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.888298 0.0004037353
# ################################################################################
# mean: 4.08 std: 0.11
# Mean Inception Score : 4.083284854888916
# ################################################################################
# /content/AttnGAN/models/netG_epoch_130/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9153531 0.00033362003
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.91449463 0.00034006545
# ################################################################################
# mean: 4.25 std: 0.15
# Mean Inception Score : 4.249710559844971
# ################################################################################
# /content/AttnGAN/models/netG_epoch_140/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.8998383 0.00036076352
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9198611 0.00026989385
# ################################################################################
# mean: 4.11 std: 0.11
# Mean Inception Score : 4.10706901550293
# ################################################################################
# /content/AttnGAN/models/netG_epoch_150/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.8920721 0.0003272979
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9435252 0.00022872628
# ################################################################################
# mean: 4.17 std: 0.18
# Mean Inception Score : 4.171746253967285
# ################################################################################
# /content/AttnGAN/models/netG_epoch_160/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.93646395 0.00032732266
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.8978776 0.0004395188
# ################################################################################
# mean: 4.00 std: 0.13
# Mean Inception Score : 3.9988982677459717
# ################################################################################
# /content/AttnGAN/models/netG_epoch_170/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9157269 0.00016098228
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9230333 0.00033393648
# ################################################################################
# mean: 4.07 std: 0.14
# Mean Inception Score : 4.071536064147949
# ################################################################################
# /content/AttnGAN/models/netG_epoch_180/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.869561 0.00015825349
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.91924584 0.0004744811
# ################################################################################
# mean: 4.01 std: 0.12
# Mean Inception Score : 4.011922836303711
# ################################################################################
# /content/AttnGAN/models/netG_epoch_190/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.95421076 7.9887344e-05
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.89908975 0.00023425849
# ################################################################################
# mean: 4.13 std: 0.17
# Mean Inception Score : 4.132235527038574
# ################################################################################
# /content/AttnGAN/models/netG_epoch_200/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.94913155 0.00019260995
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.92992437 0.00024176686
# ################################################################################
# mean: 4.20 std: 0.15
# Mean Inception Score : 4.2048540115356445
# ################################################################################
# /content/AttnGAN/models/netG_epoch_210/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9183584 0.0003770789
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9621935 0.00012591109
# ################################################################################
# mean: 4.18 std: 0.20
# Mean Inception Score : 4.181052207946777
# ################################################################################
# /content/AttnGAN/models/netG_epoch_220/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.92908376 0.000120824334
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.94119704 0.00019881483
# ################################################################################
# mean: 4.36 std: 0.21
# Mean Inception Score : 4.36098575592041
# ################################################################################
# /content/AttnGAN/models/netG_epoch_230/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.9843137 -1.0
# pred (64, 50) 0.88781416 0.00042079337
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.92297775 0.00037907113
# ################################################################################
# mean: 4.25 std: 0.18
# Mean Inception Score : 4.246184349060059
# ################################################################################
# /content/AttnGAN/models/netG_epoch_240/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.86305857 0.00043268103
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9071489 0.0002451201
# ################################################################################
# mean: 4.19 std: 0.19
# Mean Inception Score : 4.188228607177734
# ################################################################################
# /content/AttnGAN/models/netG_epoch_250/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.86876816 0.00026887938
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9077107 0.00038207686
# ################################################################################
# mean: 4.22 std: 0.19
# Mean Inception Score : 4.217339515686035
# ################################################################################
# /content/AttnGAN/models/netG_epoch_260/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.9843137 -1.0
# pred (64, 50) 0.9519933 0.00011081042
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9058635 0.00028066174
# ################################################################################
# mean: 4.35 std: 0.20
# Mean Inception Score : 4.353170394897461
# ################################################################################
# /content/AttnGAN/models/netG_epoch_270/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.9843137 -1.0
# pred (64, 50) 0.9679605 8.1006874e-05
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.893523 0.00014862555
# ################################################################################
# mean: 4.14 std: 0.11
# Mean Inception Score : 4.139995098114014
# ################################################################################
# /content/AttnGAN/models/netG_epoch_280/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.9843137 -1.0
# pred (64, 50) 0.9245043 0.00013034538
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.92256993 0.00022540914
# ################################################################################
# mean: 4.08 std: 0.16
# Mean Inception Score : 4.084005832672119
# ################################################################################
# /content/AttnGAN/models/netG_epoch_290/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.93569493 0.0002173039
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9282735 0.00023597716
# ################################################################################
# mean: 4.43 std: 0.22
# Mean Inception Score : 4.426257133483887
# ################################################################################
# /content/AttnGAN/models/netG_epoch_300/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.9843137 -1.0
# pred (64, 50) 0.92449194 0.00031341024
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9015596 0.00018870005
# ################################################################################
# mean: 4.39 std: 0.11
# Mean Inception Score : 4.392752170562744
# ################################################################################
# /content/AttnGAN/models/netG_epoch_310/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.91353625 0.00017029846
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9525868 0.00021227218
# ################################################################################
# mean: 4.36 std: 0.17
# Mean Inception Score : 4.3612961769104
# ################################################################################
# /content/AttnGAN/models/netG_epoch_320/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.9843137 -1.0
# pred (64, 50) 0.90472573 0.00018668902
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.90376395 0.00022549352
# ################################################################################
# mean: 4.15 std: 0.15
# Mean Inception Score : 4.149290561676025
# ################################################################################
# /content/AttnGAN/models/netG_epoch_330/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.9764706 -1.0
# pred (64, 50) 0.88185704 0.00019093681
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.94398654 0.00012374696
# ################################################################################
# mean: 4.22 std: 0.16
# Mean Inception Score : 4.218422889709473
# ################################################################################
# /content/AttnGAN/models/netG_epoch_340/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9441633 0.00030375214
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.91424364 0.00024145689
# ################################################################################
# mean: 4.27 std: 0.25
# Mean Inception Score : 4.271650791168213
# ################################################################################
# /content/AttnGAN/models/netG_epoch_350/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.90343773 0.00017047358
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.93282187 0.00017188105
# ################################################################################
# mean: 4.31 std: 0.14
# Mean Inception Score : 4.308480262756348
# ################################################################################
# /content/AttnGAN/models/netG_epoch_360/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9498084 0.0001934735
# Batch  25
# inp (64, 299, 299, 3) 0.9843137 -1.0
# pred (64, 50) 0.9319557 0.00026325686
# ################################################################################
# mean: 4.38 std: 0.19
# Mean Inception Score : 4.376046657562256
# ################################################################################
# /content/AttnGAN/models/netG_epoch_370/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9678702 0.00013828339
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9672637 0.0001329933
# ################################################################################
# mean: 4.42 std: 0.15
# Mean Inception Score : 4.415604591369629
# ################################################################################
# /content/AttnGAN/models/netG_epoch_380/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.92902595 0.0003984734
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9327237 0.00010802569
# ################################################################################
# mean: 4.34 std: 0.16
# Mean Inception Score : 4.34196662902832
# ################################################################################
# /content/AttnGAN/models/netG_epoch_390/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.9843137 -1.0
# pred (64, 50) 0.9292121 0.00026257936
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.908048 0.0002152615
# ################################################################################
# mean: 4.30 std: 0.24
# Mean Inception Score : 4.304604530334473
# ################################################################################
# /content/AttnGAN/models/netG_epoch_400/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.8791 0.00030083323
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.92014724 0.00021372068
# ################################################################################
# mean: 4.40 std: 0.25
# Mean Inception Score : 4.399299621582031
# ################################################################################
# /content/AttnGAN/models/netG_epoch_410/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.93187064 0.00011663755
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.8860858 0.0004621947
# ################################################################################
# mean: 4.30 std: 0.10
# Mean Inception Score : 4.301623344421387
# ################################################################################
# /content/AttnGAN/models/netG_epoch_420/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9126203 0.00017718907
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9148009 0.00027586654
# ################################################################################
# mean: 4.46 std: 0.16
# Mean Inception Score : 4.456462860107422
# ################################################################################
# /content/AttnGAN/models/netG_epoch_430/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9389751 0.00042339932
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9477829 0.00018087584
# ################################################################################
# mean: 4.22 std: 0.08
# Mean Inception Score : 4.216495990753174
# ################################################################################
# /content/AttnGAN/models/netG_epoch_440/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.89419204 0.00019297736
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9446486 0.0002362556
# ################################################################################
# mean: 4.36 std: 0.09
# Mean Inception Score : 4.357480525970459
# ################################################################################
# /content/AttnGAN/models/netG_epoch_450/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.96862745 -1.0
# pred (64, 50) 0.9365413 0.00026313294
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.910711 0.0002921008
# ################################################################################
# mean: 4.30 std: 0.11
# Mean Inception Score : 4.301202774047852
# ################################################################################
# /content/AttnGAN/models/netG_epoch_460/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.92575 9.5220596e-05
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.96833056 7.1306305e-05
# ################################################################################
# mean: 4.27 std: 0.15
# Mean Inception Score : 4.268640041351318
# ################################################################################
# /content/AttnGAN/models/netG_epoch_470/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.91542125 0.00029421158
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.90459484 0.00023778767
# ################################################################################
# mean: 4.33 std: 0.12
# Mean Inception Score : 4.326165676116943
# ################################################################################
# /content/AttnGAN/models/netG_epoch_480/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.94930845 0.00013933385
# Batch  25
# inp (64, 299, 299, 3) 0.9843137 -1.0
# pred (64, 50) 0.9379446 0.00039184376
# ################################################################################
# mean: 4.26 std: 0.18
# Mean Inception Score : 4.263941287994385
# ################################################################################
# /content/AttnGAN/models/netG_epoch_490/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.9843137 -1.0
# pred (64, 50) 0.95205414 0.00012747565
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.91866726 0.00020834034
# ################################################################################
# mean: 4.30 std: 0.13
# Mean Inception Score : 4.299553871154785
# ################################################################################
# /content/AttnGAN/models/netG_epoch_500/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.9843137 -1.0
# pred (64, 50) 0.8798528 0.00021950496
# Batch  25
# inp (64, 299, 299, 3) 0.9843137 -1.0
# pred (64, 50) 0.9243241 8.804027e-05
# ################################################################################
# mean: 4.25 std: 0.10
# Mean Inception Score : 4.252569675445557
# ################################################################################
# /content/AttnGAN/models/netG_epoch_510/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.9764706 -1.0
# pred (64, 50) 0.92367333 0.00012971589
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9370146 0.00026091936
# ################################################################################
# mean: 4.32 std: 0.14
# Mean Inception Score : 4.315600395202637
# ################################################################################
# /content/AttnGAN/models/netG_epoch_520/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9342778 0.000302373
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.8854574 0.00017934742
# ################################################################################
# mean: 4.31 std: 0.14
# Mean Inception Score : 4.307301044464111
# ################################################################################
# /content/AttnGAN/models/netG_epoch_530/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9182631 0.00025059888
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9154084 0.00032290426
# ################################################################################
# mean: 4.23 std: 0.19
# Mean Inception Score : 4.231057167053223
# ################################################################################
# /content/AttnGAN/models/netG_epoch_540/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9454794 0.00017744448
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9575596 7.963338e-05
# ################################################################################
# mean: 4.32 std: 0.15
# Mean Inception Score : 4.320651531219482
# ################################################################################
# /content/AttnGAN/models/netG_epoch_550/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9139711 0.0001307406
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9190067 0.00022980831
# ################################################################################
# mean: 4.52 std: 0.17
# Mean Inception Score : 4.5173797607421875
# ################################################################################
# /content/AttnGAN/models/netG_epoch_560/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.9843137 -1.0
# pred (64, 50) 0.9234916 0.00017943491
# Batch  25
# inp (64, 299, 299, 3) 0.9843137 -1.0
# pred (64, 50) 0.9289933 0.00031972665
# ################################################################################
# mean: 4.54 std: 0.17
# Mean Inception Score : 4.5387444496154785
# ################################################################################
# /content/AttnGAN/models/netG_epoch_570/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.92220944 0.0002899224
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9519946 0.0002916647
# ################################################################################
# mean: 4.40 std: 0.13
# Mean Inception Score : 4.40099573135376
# ################################################################################
# /content/AttnGAN/models/netG_epoch_580/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.93499565 0.00018807818
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9244835 0.00018782595
# ################################################################################
# mean: 4.46 std: 0.14
# Mean Inception Score : 4.458465576171875
# ################################################################################
# /content/AttnGAN/models/netG_epoch_590/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.91497463 0.00041127848
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.96189344 0.00016661461
# ################################################################################
# mean: 4.35 std: 0.16
# Mean Inception Score : 4.34783935546875
# ################################################################################
# /content/AttnGAN/models/netG_epoch_600/valid/single/
# images 2912 (256, 256, 3)
# Batch  0
# inp (64, 299, 299, 3) 0.9764706 -1.0
# pred (64, 50) 0.93480486 0.00022174198
# Batch  25
# inp (64, 299, 299, 3) 0.99215686 -1.0
# pred (64, 50) 0.9470869 8.671013e-05
# ################################################################################
# mean: 4.53 std: 0.15
# Mean Inception Score : 4.530726432800293
# ################################################################################
